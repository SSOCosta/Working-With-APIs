# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %% [markdown]
# # Registered Domain Names Search

# %%
import pandas as pd
import requests
import json

# %%
# Registered Domain Names Search
domains_response = requests.get ('https://api.domainsdb.info/v1/domains/search?domain=Lego')
print("Domains:", domains_response.status_code)
# Out:
# Domains: 200

# %%
results = domains_response.json()
results
# Out:
# {'domains': [{'domain': 'lego-star.net',
#    'create_date': '2023-11-19T00:22:04.596649',
#    'update_date': '2023-11-19T00:22:04.596651',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-asobi.com',
#    'create_date': '2023-11-19T00:20:50.055211',
#    'update_date': '2023-11-19T00:20:50.055213',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-auktionshaus.com',
#    'create_date': '2023-11-19T00:20:50.055414',
#    'update_date': '2023-11-19T00:20:50.055416',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-benelic-synertech-app.com',
#    'create_date': '2023-11-19T00:20:50.055624',
#    'update_date': '2023-11-19T00:20:50.055626',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-star.com',
#    'create_date': '2023-11-19T00:20:50.055807',
#    'update_date': '2023-11-19T00:20:50.055809',
#    'country': 'US',
#    'isDead': 'False',
#    'A': ['104.27.173.148', '104.27.172.148'],
#    'NS': ['cory.ns.cloudflare.com', 'leia.ns.cloudflare.com'],
#    'CNAME': None,
#    'MX': None,
#    'TXT': ['ca3-65d8076a04c24b2c869a722af7290818']},
#   {'domain': 'pick-up-your-lego-set.com',
#    'create_date': '2023-11-17T16:06:11.619604',
#    'update_date': '2023-11-17T16:06:11.619606',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-verse.com',
#    'create_date': '2023-11-17T16:05:59.843311',
#    'update_date': '2023-11-17T16:05:59.843313',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-outlet.com',
#    'create_date': '2023-11-17T16:05:59.843157',
#    'update_date': '2023-11-17T16:05:59.843159',
#    'country': 'US',
#    'isDead': 'False',
#    'A': ['172.67.174.203', '104.21.72.40'],
#    'NS': ['mike.ns.cloudflare.com', 'candy.ns.cloudflare.com'],
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-ru.ru',
#    'create_date': '2023-11-16T06:03:43.891699',
#    'update_date': '2023-11-16T06:03:43.891701',
#    'country': 'RU',
#    'isDead': 'False',
#    'A': ['195.208.1.110'],
#    'NS': ['ns3.nic.ru', 'ns4.nic.ru', 'ns8.nic.ru'],
#    'CNAME': None,
#    'MX': [{'exchange': 'mx03.nicmail.ru', 'priority': 20},
#     {'exchange': 'mx02.nicmail.ru', 'priority': 5},
#     {'exchange': 'mx01.nicmail.ru', 'priority': 10}],
#    'TXT': ['v=spf1 redirect=nicmail.ru']},
#   {'domain': 'buy-lego-sets.com',
#    'create_date': '2023-11-10T22:48:57.376119',
#    'update_date': '2023-11-10T22:48:57.376121',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-cars.ru',
#    'create_date': '2023-11-09T15:16:54.220457',
#    'update_date': '2023-11-09T15:16:54.220460',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-sets-us-1965991.com',
#    'create_date': '2023-11-09T15:15:20.447219',
#    'update_date': '2023-11-09T15:15:20.447221',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-island.com',
#    'create_date': '2023-11-09T15:15:20.447026',
#    'update_date': '2023-11-09T15:15:20.447029',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-sets-us-4297430.world',
#    'create_date': '2023-11-08T07:38:28.535746',
#    'update_date': '2023-11-08T07:38:28.535749',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-signup.com',
#    'create_date': '2023-10-31T09:38:18.853136',
#    'update_date': '2023-10-31T09:38:18.853138',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-home.net',
#    'create_date': '2023-10-30T16:23:27.452706',
#    'update_date': '2023-10-30T16:23:27.452707',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-occasion.com',
#    'create_date': '2023-10-27T20:57:03.626205',
#    'update_date': '2023-10-27T20:57:03.626207',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-33.com',
#    'create_date': '2023-10-26T11:07:46.423286',
#    'update_date': '2023-10-26T11:07:46.423288',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-promo.com',
#    'create_date': '2023-10-26T11:07:46.423444',
#    'update_date': '2023-10-26T11:07:46.423446',
#    'country': 'US',
#    'isDead': 'False',
#    'A': ['104.28.31.65', '104.28.30.65'],
#    'NS': ['uma.ns.cloudflare.com', 'chad.ns.cloudflare.com'],
#    'CNAME': None,
#    'MX': None,
#    'TXT': ['ca3-80a3b8f657ee4affa6b51393ea79d247']},
#   {'domain': 'lego-egypt.com',
#    'create_date': '2023-10-23T17:02:51.960600',
#    'update_date': '2023-10-23T17:02:51.960602',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-geschenkideen.de',
#    'create_date': '2023-10-20T00:58:25.803915',
#    'update_date': '2023-10-20T00:58:25.803917',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-zakopane.com',
#    'create_date': '2023-10-18T16:05:12.822179',
#    'update_date': '2023-10-18T16:05:12.822181',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-kingdom.com',
#    'create_date': '2023-10-18T16:05:12.821812',
#    'update_date': '2023-10-18T16:05:12.821814',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-krupowki.com',
#    'create_date': '2023-10-18T16:05:12.821977',
#    'update_date': '2023-10-18T16:05:12.821980',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'asso-lego-pf.com',
#    'create_date': '2023-10-17T05:15:46.756249',
#    'update_date': '2023-10-17T05:15:46.756251',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-lordfilm.ru',
#    'create_date': '2023-10-07T13:24:59.481803',
#    'update_date': '2023-10-07T13:24:59.481805',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-liebherr-set-4312238.fyi',
#    'create_date': '2023-10-07T13:22:03.409435',
#    'update_date': '2023-10-07T13:22:03.409438',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'xn--verrcktes-mit-lego-p6b.com',
#    'create_date': '2023-10-04T19:07:09.651270',
#    'update_date': '2023-10-04T19:07:09.651272',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'xn--lego-mfb.com',
#    'create_date': '2023-10-04T19:06:00.055901',
#    'update_date': '2023-10-04T19:06:00.055903',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'virtual-lego-superstore.com',
#    'create_date': '2023-10-04T18:35:13.600175',
#    'update_date': '2023-10-04T18:35:13.600177',
#    'country': 'US',
#    'isDead': 'False',
#    'A': ['165.160.15.20', '165.160.13.20'],
#    'NS': ['ns2.domainnetwork.se', 'ns.domainnetwork.se'],
#    'CNAME': None,
#    'MX': None,
#    'TXT': ['v=spf1 -all']},
#   {'domain': 'vintage-lego-toys.com',
#    'create_date': '2023-10-04T18:34:21.402358',
#    'update_date': '2023-10-04T18:34:21.402360',
#    'country': 'IE',
#    'isDead': 'False',
#    'A': ['52.210.177.133'],
#    'NS': ['ns1.jimdo.com', 'ns2.jimdo.com'],
#    'CNAME': None,
#    'MX': [{'exchange': 'mx1.jimdo.com', 'priority': 10},
#     {'exchange': 'mx2.jimdo.com', 'priority': 20}],
#    'TXT': ['v=spf1 include:spf.mandrillapp.com include:sendgrid.net include:emailsrvr.com ~all']},
#   {'domain': 'used-lego-sets.com',
#    'create_date': '2023-10-04T18:24:05.252711',
#    'update_date': '2023-10-04T18:24:05.252713',
#    'country': 'DE',
#    'isDead': 'False',
#    'A': ['81.169.185.131'],
#    'NS': ['ns1061.ui-dns.biz',
#     'ns1121.ui-dns.de',
#     'ns1026.ui-dns.com',
#     'ns1096.ui-dns.org'],
#    'CNAME': None,
#    'MX': [{'exchange': 'mx00.kundenserver.de', 'priority': 10},
#     {'exchange': 'mx01.kundenserver.de', 'priority': 11}],
#    'TXT': None},
#   {'domain': 'lego-soft.net',
#    'create_date': '2023-10-03T07:44:47.307879',
#    'update_date': '2023-10-03T07:44:47.307881',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-legends.com',
#    'create_date': '2023-10-01T23:00:46.908198',
#    'update_date': '2023-10-01T23:00:46.908200',
#    'country': 'US',
#    'isDead': 'False',
#    'A': ['64.29.145.9'],
#    'NS': ['ns2.win.net', 'ns1.win.net', 'ns3.win.net'],
#    'CNAME': None,
#    'MX': [{'exchange': 'filter2.win.net', 'priority': 200},
#     {'exchange': 'filter1.win.net', 'priority': 100}],
#    'TXT': None},
#   {'domain': 'lego-coasters.com',
#    'create_date': '2023-09-29T05:40:32.605383',
#    'update_date': '2023-09-29T05:40:32.605385',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-coasters.site',
#    'create_date': '2023-09-27T21:20:49.786650',
#    'update_date': '2023-09-27T21:20:49.786653',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-supernoelsolidaire.com',
#    'create_date': '2023-09-23T19:17:18.064583',
#    'update_date': '2023-09-23T19:17:18.064585',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-land.shop',
#    'create_date': '2023-09-22T10:51:06.090396',
#    'update_date': '2023-09-22T10:51:06.090398',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-rus.ru',
#    'create_date': '2023-09-21T02:04:50.498607',
#    'update_date': '2023-09-21T02:04:50.498609',
#    'country': 'RU',
#    'isDead': 'False',
#    'A': ['31.31.198.119'],
#    'NS': ['ns2.hosting.reg.ru', 'ns1.hosting.reg.ru'],
#    'CNAME': None,
#    'MX': [{'exchange': 'mx2.hosting.reg.ru', 'priority': 20},
#     {'exchange': 'mx1.hosting.reg.ru', 'priority': 10}],
#    'TXT': ['v=spf1 ip4:31.31.198.119 a mx include:_spf.hosting.reg.ru ~all']},
#   {'domain': 'lego-igraonica.net',
#    'create_date': '2023-09-21T02:04:28.869995',
#    'update_date': '2023-09-21T02:04:28.869997',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-rus.store',
#    'create_date': '2023-09-21T02:01:13.313016',
#    'update_date': '2023-09-21T02:01:13.313018',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-lady.com',
#    'create_date': '2023-09-18T19:49:30.135767',
#    'update_date': '2023-09-18T19:49:30.135769',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-88.com',
#    'create_date': '2023-09-13T20:53:25.100478',
#    'update_date': '2023-09-13T20:53:25.100481',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-gather.com',
#    'create_date': '2023-09-09T18:48:01.198427',
#    'update_date': '2023-09-09T18:48:01.198429',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-warehouse.com',
#    'create_date': '2023-09-08T10:31:20.234101',
#    'update_date': '2023-09-08T10:31:20.234103',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-clearance.com',
#    'create_date': '2023-09-08T10:31:20.233904',
#    'update_date': '2023-09-08T10:31:20.233906',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-clear.com',
#    'create_date': '2023-09-08T10:31:20.233696',
#    'update_date': '2023-09-08T10:31:20.233698',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'lego-alliance.com',
#    'create_date': '2023-09-02T12:58:42.729286',
#    'update_date': '2023-09-02T12:58:42.729288',
#    'country': None,
#    'isDead': 'False',
#    'A': None,
#    'NS': None,
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'the-lego-movie.com',
#    'create_date': '2023-08-27T17:43:53.882431',
#    'update_date': '2023-08-27T17:43:53.882434',
#    'country': 'US',
#    'isDead': 'False',
#    'A': ['52.43.192.245', '50.112.199.176'],
#    'NS': ['ns4-b2.warnerbros.com',
#     'ns2-b2.warnerbros.com',
#     'ns1-b2.warnerbros.com',
#     'ns3-b2.warnerbros.com'],
#    'CNAME': None,
#    'MX': None,
#    'TXT': None},
#   {'domain': 'the-lego-store.com',
#    'create_date': '2023-08-27T17:43:53.882694',
#    'update_date': '2023-08-27T17:43:53.882698',
#    'country': 'US',
#    'isDead': 'False',
#    'A': ['165.160.15.20', '165.160.13.20'],
#    'NS': ['dns1.cscdns.net', 'dns2.cscdns.net'],
#    'CNAME': None,
#    'MX': [{'exchange': 'custmx.cscdns.net', 'priority': 10}],
#    'TXT': None}],
#  'total': 702,
#  'time': '452',
#  'next_page': None}

# %%
pd.set_option("display.max_rows", 0)
#Getting the list of dictionnaries into the dataframe
data = pd.DataFrame(results)
data.head(10)
# Out:
#                                              domains  total time next_page
# 0  {'domain': 'lego-star.net', 'create_date': '20...    702  452      None
# 1  {'domain': 'lego-asobi.com', 'create_date': '2...    702  452      None
# 2  {'domain': 'lego-auktionshaus.com', 'create_da...    702  452      None
# 3  {'domain': 'lego-benelic-synertech-app.com', '...    702  452      None
# 4  {'domain': 'lego-star.com', 'create_date': '20...    702  452      None
# 5  {'domain': 'pick-up-your-lego-set.com', 'creat...    702  452      None
# 6  {'domain': 'lego-verse.com', 'create_date': '2...    702  452      None
# 7  {'domain': 'lego-outlet.com', 'create_date': '...    702  452      None
# 8  {'domain': 'lego-ru.ru', 'create_date': '2023-...    702  452      None
# 9  {'domain': 'buy-lego-sets.com', 'create_date':...    702  452      None

# %%
def flatten_column(data, column_name):
    flattened = pd.DataFrame(dict(data[column_name])).transpose()
    columns = [str(col) for col in flattened.columns]
    flattened.columns = [column_name + '_' + colname for colname in columns]
    data = pd.concat([data, flattened], axis=1)
    data = data.drop(column_name, axis=1)
    return data

data1 = flatten_column(data, 'domains')
data1
# Out:
#     total time next_page                  domains_domain  \
# 0     702  452      None                   lego-star.net
# 1     702  452      None                  lego-asobi.com
# 2     702  452      None           lego-auktionshaus.com
# 3     702  452      None  lego-benelic-synertech-app.com
# 4     702  452      None                   lego-star.com
# 5     702  452      None       pick-up-your-lego-set.com
# 6     702  452      None                  lego-verse.com
# 7     702  452      None                 lego-outlet.com
# 8     702  452      None                      lego-ru.ru
# ..    ...  ...       ...                             ...
# 41    702  452      None                   lego-lady.com
# 42    702  452      None                     lego-88.com
# 43    702  452      None                 lego-gather.com
# 44    702  452      None              lego-warehouse.com
# 45    702  452      None              lego-clearance.com
# 46    702  452      None                  lego-clear.com
# 47    702  452      None               lego-alliance.com
# 48    702  452      None              the-lego-movie.com
# 49    702  452      None              the-lego-store.com
#
#            domains_create_date         domains_update_date domains_country  \
# 0   2023-11-19T00:22:04.596649  2023-11-19T00:22:04.596651            None
# 1   2023-11-19T00:20:50.055211  2023-11-19T00:20:50.055213            None
# 2   2023-11-19T00:20:50.055414  2023-11-19T00:20:50.055416            None
# 3   2023-11-19T00:20:50.055624  2023-11-19T00:20:50.055626            None
# 4   2023-11-19T00:20:50.055807  2023-11-19T00:20:50.055809              US
# 5   2023-11-17T16:06:11.619604  2023-11-17T16:06:11.619606            None
# 6   2023-11-17T16:05:59.843311  2023-11-17T16:05:59.843313            None
# 7   2023-11-17T16:05:59.843157  2023-11-17T16:05:59.843159              US
# 8   2023-11-16T06:03:43.891699  2023-11-16T06:03:43.891701              RU
# ..                         ...                         ...             ...
# 41  2023-09-18T19:49:30.135767  2023-09-18T19:49:30.135769            None
# 42  2023-09-13T20:53:25.100478  2023-09-13T20:53:25.100481            None
# 43  2023-09-09T18:48:01.198427  2023-09-09T18:48:01.198429            None
# 44  2023-09-08T10:31:20.234101  2023-09-08T10:31:20.234103            None
# 45  2023-09-08T10:31:20.233904  2023-09-08T10:31:20.233906            None
# 46  2023-09-08T10:31:20.233696  2023-09-08T10:31:20.233698            None
# 47  2023-09-02T12:58:42.729286  2023-09-02T12:58:42.729288            None
# 48  2023-08-27T17:43:53.882431  2023-08-27T17:43:53.882434              US
# 49  2023-08-27T17:43:53.882694  2023-08-27T17:43:53.882698              US
#
#    domains_isDead                         domains_A  \
# 0           False                              None
# 1           False                              None
# 2           False                              None
# 3           False                              None
# 4           False  [104.27.173.148, 104.27.172.148]
# 5           False                              None
# 6           False                              None
# 7           False    [172.67.174.203, 104.21.72.40]
# 8           False                   [195.208.1.110]
# ..            ...                               ...
# 41          False                              None
# 42          False                              None
# 43          False                              None
# 44          False                              None
# 45          False                              None
# 46          False                              None
# 47          False                              None
# 48          False   [52.43.192.245, 50.112.199.176]
# 49          False    [165.160.15.20, 165.160.13.20]
#
#                                            domains_NS domains_CNAME  \
# 0                                                None          None
# 1                                                None          None
# 2                                                None          None
# 3                                                None          None
# 4    [cory.ns.cloudflare.com, leia.ns.cloudflare.com]          None
# 5                                                None          None
# 6                                                None          None
# 7   [mike.ns.cloudflare.com, candy.ns.cloudflare.com]          None
# 8                [ns3.nic.ru, ns4.nic.ru, ns8.nic.ru]          None
# ..                                                ...           ...
# 41                                               None          None
# 42                                               None          None
# 43                                               None          None
# 44                                               None          None
# 45                                               None          None
# 46                                               None          None
# 47                                               None          None
# 48  [ns4-b2.warnerbros.com, ns2-b2.warnerbros.com,...          None
# 49                 [dns1.cscdns.net, dns2.cscdns.net]          None
#
#                                            domains_MX  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8   [{'exchange': 'mx03.nicmail.ru', 'priority': 2...
# ..                                                ...
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49  [{'exchange': 'custmx.cscdns.net', 'priority':...
#
#                                domains_TXT
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4   [ca3-65d8076a04c24b2c869a722af7290818]
# 5                                     None
# 6                                     None
# 7                                     None
# 8             [v=spf1 redirect=nicmail.ru]
# ..                                     ...
# 41                                    None
# 42                                    None
# 43                                    None
# 44                                    None
# 45                                    None
# 46                                    None
# 47                                    None
# 48                                    None
# 49                                    None
#
# [50 rows x 13 columns]

# %% [markdown]
# # Public Holiday Api

# %%
# GET /api/v3/PublicHolidays/{Year}/{CountryCode}

# %%
# Checking if the Portuguese ones show up correctly - (PT is the country code)
pholiday_response = requests.get ('https://date.nager.at/api/v3/publicholidays/2023/PT')
print("Public Holiday:", pholiday_response.status_code)
# Out:
# Public Holiday: 200

# %%
results = pholiday_response.json()
results
# Out:
# [{'date': '2023-01-01',
#   'localName': 'Ano Novo',
#   'name': "New Year's Day",
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-02-21',
#   'localName': 'Carnaval',
#   'name': 'Carnival',
#   'countryCode': 'PT',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Optional']},
#  {'date': '2023-04-07',
#   'localName': 'Sexta-feira Santa',
#   'name': 'Good Friday',
#   'countryCode': 'PT',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-04-09',
#   'localName': 'Domingo de Páscoa',
#   'name': 'Easter Sunday',
#   'countryCode': 'PT',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-04-25',
#   'localName': 'Dia da Liberdade',
#   'name': 'Freedom Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-05-01',
#   'localName': 'Dia do Trabalhador',
#   'name': 'Labour Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-06-01',
#   'localName': 'Dia dos Açores',
#   'name': 'Azores Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': False,
#   'counties': ['PT-20'],
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-06-08',
#   'localName': 'Corpo de Deus',
#   'name': 'Corpus Christi',
#   'countryCode': 'PT',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-06-10',
#   'localName': 'Dia de Portugal, de Camões e das Comunidades Portuguesas',
#   'name': 'National Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-07-01',
#   'localName': 'Dia da Madeira',
#   'name': 'Madeira Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': False,
#   'counties': ['PT-30'],
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-08-15',
#   'localName': 'Assunção de Nossa Senhora',
#   'name': 'Assumption Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-10-05',
#   'localName': 'Implantação da República',
#   'name': 'Republic Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-11-01',
#   'localName': 'Dia de Todos-os-Santos',
#   'name': 'All Saints Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-12-01',
#   'localName': 'Restauração da Independência',
#   'name': 'Restoration of Independence',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-12-08',
#   'localName': 'Imaculada Conceição',
#   'name': 'Immaculate Conception',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-12-25',
#   'localName': 'Natal',
#   'name': 'Christmas Day',
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2023-12-26',
#   'localName': 'Primeira Oitava',
#   'name': "St. Stephen's Day",
#   'countryCode': 'PT',
#   'fixed': True,
#   'global': False,
#   'counties': ['PT-30'],
#   'launchYear': None,
#   'types': ['Public']}]

# %%
pd.set_option("display.max_rows", 0)
#Getting the list of dictionnaries into the dataframe
data = pd.DataFrame(results)
data
# I realized that they got the island Madeira and Açores public holidays also, and that's the reason I don't know all of them
# ... well I wish to be able to enjoy all of them :) But they look right!
# Out:
#           date                                          localName  \
# 0   2023-01-01                                           Ano Novo
# 1   2023-02-21                                           Carnaval
# 2   2023-04-07                                  Sexta-feira Santa
# 3   2023-04-09                                  Domingo de Páscoa
# 4   2023-04-25                                   Dia da Liberdade
# 5   2023-05-01                                 Dia do Trabalhador
# 6   2023-06-01                                     Dia dos Açores
# 7   2023-06-08                                      Corpo de Deus
# 8   2023-06-10  Dia de Portugal, de Camões e das Comunidades P...
# 9   2023-07-01                                     Dia da Madeira
# 10  2023-08-15                          Assunção de Nossa Senhora
# 11  2023-10-05                           Implantação da República
# 12  2023-11-01                             Dia de Todos-os-Santos
# 13  2023-12-01                       Restauração da Independência
# 14  2023-12-08                                Imaculada Conceição
# 15  2023-12-25                                              Natal
# 16  2023-12-26                                    Primeira Oitava
#
#                            name countryCode  fixed  global counties  \
# 0                New Year's Day          PT   True    True     None
# 1                      Carnival          PT  False    True     None
# 2                   Good Friday          PT  False    True     None
# 3                 Easter Sunday          PT  False    True     None
# 4                   Freedom Day          PT   True    True     None
# 5                    Labour Day          PT   True    True     None
# 6                    Azores Day          PT   True   False  [PT-20]
# 7                Corpus Christi          PT  False    True     None
# 8                  National Day          PT   True    True     None
# 9                   Madeira Day          PT   True   False  [PT-30]
# 10               Assumption Day          PT   True    True     None
# 11                 Republic Day          PT   True    True     None
# 12               All Saints Day          PT   True    True     None
# 13  Restoration of Independence          PT   True    True     None
# 14        Immaculate Conception          PT   True    True     None
# 15                Christmas Day          PT   True    True     None
# 16            St. Stephen's Day          PT   True   False  [PT-30]
#
#    launchYear       types
# 0        None    [Public]
# 1        None  [Optional]
# 2        None    [Public]
# 3        None    [Public]
# 4        None    [Public]
# 5        None    [Public]
# 6        None    [Public]
# 7        None    [Public]
# 8        None    [Public]
# 9        None    [Public]
# 10       None    [Public]
# 11       None    [Public]
# 12       None    [Public]
# 13       None    [Public]
# 14       None    [Public]
# 15       None    [Public]
# 16       None    [Public]

# %% [markdown]
# # Free and open-source brewery data

# %%
#https://api.openbrewerydb.org/v1/breweries

# %%
# Checking the list of breweries in U.S.
brewer_response = requests.get ('https://api.openbrewerydb.org/v1/breweries')
print("Geek/programming Jokes:", brewer_response.status_code)
# Out:
# Geek/programming Jokes: 200

# %%
results = brewer_response.json()
results
# Out:
# [{'id': '5128df48-79fc-4f0f-8b52-d06be54d0cec',
#   'name': '(405) Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '1716 Topeka St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Norman',
#   'state_province': 'Oklahoma',
#   'postal_code': '73069-8224',
#   'country': 'United States',
#   'longitude': '-97.46818222',
#   'latitude': '35.25738891',
#   'phone': '4058160490',
#   'website_url': 'http://www.405brewing.com',
#   'state': 'Oklahoma',
#   'street': '1716 Topeka St'},
#  {'id': '9c5a66c8-cc13-416f-a5d9-0a769c87d318',
#   'name': '(512) Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '407 Radam Ln Ste F200',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Austin',
#   'state_province': 'Texas',
#   'postal_code': '78745-1197',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '5129211545',
#   'website_url': 'http://www.512brewing.com',
#   'state': 'Texas',
#   'street': '407 Radam Ln Ste F200'},
#  {'id': '34e8c68b-6146-453f-a4b9-1f6cd99a5ada',
#   'name': '1 of Us Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '8100 Washington Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mount Pleasant',
#   'state_province': 'Wisconsin',
#   'postal_code': '53406-3920',
#   'country': 'United States',
#   'longitude': '-87.88336350209435',
#   'latitude': '42.72010826899558',
#   'phone': '2624847553',
#   'website_url': 'https://www.1ofusbrewing.com',
#   'state': 'Wisconsin',
#   'street': '8100 Washington Ave'},
#  {'id': 'ef970757-fe42-416f-931d-722451f1f59c',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1501 E St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'San Diego',
#   'state_province': 'California',
#   'postal_code': '92101-6618',
#   'country': 'United States',
#   'longitude': '-117.129593',
#   'latitude': '32.714813',
#   'phone': '6195782311',
#   'website_url': 'http://10barrel.com',
#   'state': 'California',
#   'street': '1501 E St'},
#  {'id': '6d14b220-8926-4521-8d19-b98a2d6ec3db',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '62970 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97701-9847',
#   'country': 'United States',
#   'longitude': '-121.281706',
#   'latitude': '44.08683531',
#   'phone': '5415851007',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Oregon',
#   'street': '62970 18th St'},
#  {'id': 'e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1135 NW Galveston Ave Ste B',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97703-2465',
#   'country': 'United States',
#   'longitude': '-121.3288021',
#   'latitude': '44.0575649',
#   'phone': '5415851007',
#   'website_url': None,
#   'state': 'Oregon',
#   'street': '1135 NW Galveston Ave Ste B'},
#  {'id': 'e432899b-7f58-455f-9c7b-9a6e2130a1e0',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1411 NW Flanders St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Portland',
#   'state_province': 'Oregon',
#   'postal_code': '97209-2620',
#   'country': 'United States',
#   'longitude': '-122.6855056',
#   'latitude': '45.5259786',
#   'phone': '5032241700',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Oregon',
#   'street': '1411 NW Flanders St'},
#  {'id': '9f1852da-c312-42da-9a31-097bac81c4c0',
#   'name': '10 Barrel Brewing Co - Bend Pub',
#   'brewery_type': 'large',
#   'address_1': '62950 NE 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97701',
#   'country': 'United States',
#   'longitude': '-121.2809536',
#   'latitude': '44.0912109',
#   'phone': '5415851007',
#   'website_url': None,
#   'state': 'Oregon',
#   'street': '62950 NE 18th St'},
#  {'id': 'ea4f30c0-bce6-416b-8904-fab4055a7362',
#   'name': '10 Barrel Brewing Co - Boise',
#   'brewery_type': 'large',
#   'address_1': '826 W Bannock St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Boise',
#   'state_province': 'Idaho',
#   'postal_code': '83702-5857',
#   'country': 'United States',
#   'longitude': '-116.202929',
#   'latitude': '43.618516',
#   'phone': '2083445870',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Idaho',
#   'street': '826 W Bannock St'},
#  {'id': '1988eb86-f0a2-4674-ba04-02454efa0d31',
#   'name': '10 Barrel Brewing Co - Denver',
#   'brewery_type': 'large',
#   'address_1': '2620 Walnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Denver',
#   'state_province': 'Colorado',
#   'postal_code': '80205-2231',
#   'country': 'United States',
#   'longitude': '-104.9853655',
#   'latitude': '39.7592508',
#   'phone': '7205738992',
#   'website_url': None,
#   'state': 'Colorado',
#   'street': '2620 Walnut St'},
#  {'id': '1ecc330f-6275-42a5-b14e-00adbed62752',
#   'name': '10 Torr Distilling and Brewing',
#   'brewery_type': 'micro',
#   'address_1': '490 Mill St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Reno',
#   'state_province': 'Nevada',
#   'postal_code': '89502',
#   'country': 'United States',
#   'longitude': '-119.7732015',
#   'latitude': '39.5171702',
#   'phone': '7755307014',
#   'website_url': 'http://www.10torr.com',
#   'state': 'Nevada',
#   'street': '490 Mill St'},
#  {'id': '7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3',
#   'name': '10-56 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '400 Brown Cir',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Knox',
#   'state_province': 'Indiana',
#   'postal_code': '46534',
#   'country': 'United States',
#   'longitude': '-86.627954',
#   'latitude': '41.289715',
#   'phone': '6308165790',
#   'website_url': None,
#   'state': 'Indiana',
#   'street': '400 Brown Cir'},
#  {'id': '03118499-a3d0-4c22-860d-4529509ae095',
#   'name': '101 Brewery',
#   'brewery_type': 'brewpub',
#   'address_1': '294793 US Highway 101',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Quilcene',
#   'state_province': 'Washington',
#   'postal_code': '98376-9000',
#   'country': 'United States',
#   'longitude': '-122.8755823',
#   'latitude': '47.82347577',
#   'phone': '3607656485',
#   'website_url': 'http://www.101brewery.com',
#   'state': 'Washington',
#   'street': '294793 US Highway 101'},
#  {'id': '5ae467af-66dc-4d7f-8839-44228f89b596',
#   'name': '101 North Brewing Company',
#   'brewery_type': 'closed',
#   'address_1': '1304 Scott St Ste D',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Petaluma',
#   'state_province': 'California',
#   'postal_code': '94954-7100',
#   'country': 'United States',
#   'longitude': '-122.665055',
#   'latitude': '38.27029381',
#   'phone': '7077534934',
#   'website_url': 'http://www.101northbeer.com',
#   'state': 'California',
#   'street': '1304 Scott St Ste D'},
#  {'id': '4ffda196-dd59-44a5-9eeb-5f7fd4b58f5a',
#   'name': '105 West Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '1043 Park St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Castle Rock',
#   'state_province': 'Colorado',
#   'postal_code': '80109-1585',
#   'country': 'United States',
#   'longitude': '-104.8667206',
#   'latitude': '39.38269495',
#   'phone': '3033257321',
#   'website_url': 'http://www.105westbrewing.com',
#   'state': 'Colorado',
#   'street': '1043 Park St'},
#  {'id': '42aa37d5-8384-4ffe-8c81-7c982eff0384',
#   'name': '10K Brewing',
#   'brewery_type': 'micro',
#   'address_1': '2005 2nd Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Anoka',
#   'state_province': 'Minnesota',
#   'postal_code': '55303-2243',
#   'country': 'United States',
#   'longitude': '-93.38952559',
#   'latitude': '45.19812039',
#   'phone': '7633924753',
#   'website_url': 'http://10KBrew.com',
#   'state': 'Minnesota',
#   'street': '2005 2nd Ave'},
#  {'id': '232e8f62-9afc-45f5-b4bc-582c26b5c43b',
#   'name': '10th District Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '491 Washington St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Abington',
#   'state_province': 'Massachusetts',
#   'postal_code': '02351-2419',
#   'country': 'United States',
#   'longitude': '-70.94594149',
#   'latitude': '42.10591754',
#   'phone': '7813071554',
#   'website_url': 'http://www.10thdistrictbrewing.com',
#   'state': 'Massachusetts',
#   'street': '491 Washington St'},
#  {'id': '08f78223-24f8-4b71-b381-ea19a5bd82df',
#   'name': '11 Below Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '6820 Bourgeois Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Houston',
#   'state_province': 'Texas',
#   'postal_code': '77066-3107',
#   'country': 'United States',
#   'longitude': '-95.5186591',
#   'latitude': '29.9515464',
#   'phone': '2814442337',
#   'website_url': 'http://www.11belowbrewing.com',
#   'state': 'Texas',
#   'street': '6820 Bourgeois Rd'},
#  {'id': '58293321-14ae-49d7-9a7b-08436c9e63a6',
#   'name': '1188 Brewing Co',
#   'brewery_type': 'brewpub',
#   'address_1': '141 E Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'John Day',
#   'state_province': 'Oregon',
#   'postal_code': '97845-1210',
#   'country': 'United States',
#   'longitude': '-118.9218754',
#   'latitude': '44.4146563',
#   'phone': '5415751188',
#   'website_url': 'http://www.1188brewing.com',
#   'state': 'Oregon',
#   'street': '141 E Main St'},
#  {'id': 'e5f3e72a-fee2-4813-82cf-f2e53b439ae6',
#   'name': '12 Acres Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': 'Unnamed Street',
#   'address_2': 'Clonmore',
#   'address_3': None,
#   'city': 'Killeshin',
#   'state_province': 'Laois',
#   'postal_code': 'R93 X3X8',
#   'country': 'Ireland',
#   'longitude': '-6.979343891',
#   'latitude': '52.84930763',
#   'phone': '353599107299',
#   'website_url': 'https://12acresbrewing.ie/',
#   'state': 'Laois',
#   'street': 'Unnamed Street'},
#  {'id': 'd81ff708-b5d2-478f-af6a-6d40f5beb9ac',
#   'name': '12 Gates Brewing Company',
#   'brewery_type': 'brewpub',
#   'address_1': '80 Earhart Dr Ste 20',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Williamsville',
#   'state_province': 'New York',
#   'postal_code': '14221-7804',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '7169066600',
#   'website_url': 'http://www.12gatesbrewing.com',
#   'state': 'New York',
#   'street': '80 Earhart Dr Ste 20'},
#  {'id': 'fb94830f-6196-4f59-9189-c9060b778085',
#   'name': '12 West Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '3000 E Ray Rd Bldg 6',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Gilbert',
#   'state_province': 'Arizona',
#   'postal_code': '85296-7832',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6023395014',
#   'website_url': 'http://www.12westbrewing.com',
#   'state': 'Arizona',
#   'street': '3000 E Ray Rd Bldg 6'},
#  {'id': '0faa0fb2-fffa-416d-9eab-46f67477c8ef',
#   'name': '12 West Brewing Company - Production Facility',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mesa',
#   'state_province': 'Arizona',
#   'postal_code': '85207',
#   'country': 'United States',
#   'longitude': '-111.5860662',
#   'latitude': '33.436188',
#   'phone': None,
#   'website_url': None,
#   'state': 'Arizona',
#   'street': None},
#  {'id': 'e54c2f02-acd6-4172-861d-fcfa54c8701a',
#   'name': '122 West Brewing Co',
#   'brewery_type': 'closed',
#   'address_1': '2416 Meridian St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bellingham',
#   'state_province': 'Washington',
#   'postal_code': '98225-2405',
#   'country': 'United States',
#   'longitude': '-122.485982',
#   'latitude': '48.7621709',
#   'phone': '3603063285',
#   'website_url': 'https://www.122westbrew.com/',
#   'state': 'Washington',
#   'street': '2416 Meridian St'},
#  {'id': 'd5cb896d-3e99-4e19-9693-5e06ce987e53',
#   'name': '127 Brewing',
#   'brewery_type': 'micro',
#   'address_1': '3090 Shirley Dr',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Jackson',
#   'state_province': 'Michigan',
#   'postal_code': '49201-7010',
#   'country': 'United States',
#   'longitude': '-84.43116792',
#   'latitude': '42.28667212',
#   'phone': '5172581346',
#   'website_url': None,
#   'state': 'Michigan',
#   'street': '3090 Shirley Dr'},
#  {'id': '06e9fffb-e820-45c9-b107-b52b51013e8f',
#   'name': '12Degree Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '820 Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Louisville',
#   'state_province': 'Colorado',
#   'postal_code': '80027-1865',
#   'country': 'United States',
#   'longitude': '-105.1319826',
#   'latitude': '39.9782443',
#   'phone': '3035791004',
#   'website_url': 'http://www.12degree.com',
#   'state': 'Colorado',
#   'street': '820 Main St'},
#  {'id': '50521ef7-f543-4c5d-98b1-0d0ee1a2be01',
#   'name': '12welve Eyes Brewing',
#   'brewery_type': 'micro',
#   'address_1': '141 E 4th St Ste LL2',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Saint Paul',
#   'state_province': 'Minnesota',
#   'postal_code': '55101-1639',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6514938106',
#   'website_url': 'http://www.12welveEyes.com',
#   'state': 'Minnesota',
#   'street': '141 E 4th St Ste LL2'},
#  {'id': '950180bd-29c9-46b3-ad0c-e6f09799ec7f',
#   'name': '13 Below Brewery',
#   'brewery_type': 'micro',
#   'address_1': '7391 Forbes Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Cincinnati',
#   'state_province': 'Ohio',
#   'postal_code': '45233-1013',
#   'country': 'United States',
#   'longitude': '-84.70634815',
#   'latitude': '39.12639764',
#   'phone': '5139750613',
#   'website_url': 'http://www.13belowbrewery.com',
#   'state': 'Ohio',
#   'street': '7391 Forbes Rd'},
#  {'id': '45119c56-345b-4adc-b481-c5cf7bfe98c4',
#   'name': '13 Stripes Brewery',
#   'brewery_type': 'brewpub',
#   'address_1': '250 Mill St, Suite PW3101',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Taylors',
#   'state_province': 'South Carolina',
#   'postal_code': '29687',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '8643491430',
#   'website_url': 'http://www.13StripesBrewery.com',
#   'state': 'South Carolina',
#   'street': '250 Mill St, Suite PW3101'},
#  {'id': '936c3d7e-5d54-4459-b72c-117cdda059b4',
#   'name': '13 Virtues Brewing Co',
#   'brewery_type': 'brewpub',
#   'address_1': '6410 SE Milwaukie Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Portland',
#   'state_province': 'Oregon',
#   'postal_code': '97202-5518',
#   'country': 'United States',
#   'longitude': '-122.6487531',
#   'latitude': '45.4762536',
#   'phone': '5032393831',
#   'website_url': 'http://www.13virtuesbrewing.com',
#   'state': 'Oregon',
#   'street': '6410 SE Milwaukie Ave'},
#  {'id': '5c53b314-ebab-4e3e-89be-e4139d9318ae',
#   'name': '1323 R & D',
#   'brewery_type': 'micro',
#   'address_1': '1323 Capital Blvd 1323 R and D',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Raleigh',
#   'state_province': 'North Carolina',
#   'postal_code': '27603-1117',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '9199775654',
#   'website_url': 'http://www.1323rnd.com',
#   'state': 'North Carolina',
#   'street': '1323 Capital Blvd 1323 R and D'},
#  {'id': '4788221a-a03b-458c-9084-4cadd69ade6d',
#   'name': '14 Cannons Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '31125 Via Colinas Ste 907',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Westlake Village',
#   'state_province': 'California',
#   'postal_code': '91362-3974',
#   'country': 'United States',
#   'longitude': '-118.802397',
#   'latitude': '34.15334',
#   'phone': '8186996165',
#   'website_url': 'http://14cannons.com',
#   'state': 'California',
#   'street': '31125 Via Colinas Ste 907'},
#  {'id': 'b7b68d22-5045-4501-b9bf-ec94946eaffc',
#   'name': '14 Lakes Brewery',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Crosslake',
#   'state_province': 'Minnesota',
#   'postal_code': '56442',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '2186924129',
#   'website_url': None,
#   'state': 'Minnesota',
#   'street': None},
#  {'id': '4b677b60-fef1-42e2-90ef-dadc1bd7fb06',
#   'name': '14er Brewing Company',
#   'brewery_type': 'proprietor',
#   'address_1': '2801 Walnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Denver',
#   'state_province': 'Colorado',
#   'postal_code': '80205-2235',
#   'country': 'United States',
#   'longitude': '-104.9839636',
#   'latitude': '39.7614112',
#   'phone': '7207731437',
#   'website_url': 'http://www.14erBrewing.com',
#   'state': 'Colorado',
#   'street': '2801 Walnut St'},
#  {'id': '6c53984f-fac1-4ea7-9c44-44e25897c71a',
#   'name': '14th Star Brewing',
#   'brewery_type': 'micro',
#   'address_1': '133 N Main St Ste 7',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Saint Albans',
#   'state_province': 'Vermont',
#   'postal_code': '05478-1735',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '8025285988',
#   'website_url': 'http://www.14thstarbrewing.com',
#   'state': 'Vermont',
#   'street': '133 N Main St Ste 7'},
#  {'id': '85192a9c-58a4-48c3-bd9d-496d09d22aa3',
#   'name': '16 Lots Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '753 Reading Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mason',
#   'state_province': 'Ohio',
#   'postal_code': '45040-1303',
#   'country': 'United States',
#   'longitude': '-84.3183801',
#   'latitude': '39.3545967',
#   'phone': '5134863672',
#   'website_url': 'http://www.16lots.com',
#   'state': 'Ohio',
#   'street': '753 Reading Rd'},
#  {'id': '284b44f8-6ccb-4cd6-8d06-f2ad882a47c3',
#   'name': '16 Mile Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '413 S Bedford St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Georgetown',
#   'state_province': 'Delaware',
#   'postal_code': '19947-1849',
#   'country': 'United States',
#   'longitude': '-75.37816436',
#   'latitude': '38.6788938',
#   'phone': '3022538816',
#   'website_url': 'http://www.16milebrewery.com',
#   'state': 'Delaware',
#   'street': '413 S Bedford St'},
#  {'id': 'ee6d39c6-092f-4623-8099-5b8643f70dbe',
#   'name': '16 Stone Brewpub',
#   'brewery_type': 'brewpub',
#   'address_1': '9542 Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Holland Patent',
#   'state_province': 'New York',
#   'postal_code': '13354',
#   'country': 'United States',
#   'longitude': '-75.2565195',
#   'latitude': '43.24211175',
#   'phone': '3158658500',
#   'website_url': 'http://www.16stonebrewpub.com',
#   'state': 'New York',
#   'street': '9542 Main St'},
#  {'id': 'd35b40b0-a3ff-4878-a6ee-9caa2149b521',
#   'name': '1623 Brewing CO, llc',
#   'brewery_type': 'contract',
#   'address_1': '1146 colonel Joshua Ct',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Westminister',
#   'state_province': 'Maryland',
#   'postal_code': '21157',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': None,
#   'website_url': None,
#   'state': 'Maryland',
#   'street': '1146 colonel Joshua Ct'},
#  {'id': '84bd3b3c-bd2d-4e07-bc31-b43a8c8ebf4c',
#   'name': '1717 Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '322 E Court Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Des Moines',
#   'state_province': 'Iowa',
#   'postal_code': '50309-2015',
#   'country': 'United States',
#   'longitude': '-93.6120353',
#   'latitude': '41.5872267',
#   'phone': '5152437868',
#   'website_url': 'http://1717brewing.com',
#   'state': 'Iowa',
#   'street': '322 E Court Ave'},
#  {'id': 'f41a0c47-ba9b-4547-bfed-fcbefe0fc74b',
#   'name': '1718 Ocracoke Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '1129 Irvin Garrish Hwy',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Ocracoke',
#   'state_province': 'North Carolina',
#   'postal_code': '27960',
#   'country': 'United States',
#   'longitude': '-75.97176063',
#   'latitude': '35.10715368',
#   'phone': '2529282337',
#   'website_url': 'http://www.ocracokebrewing.com',
#   'state': 'North Carolina',
#   'street': '1129 Irvin Garrish Hwy'},
#  {'id': '84d621c4-81a5-44e6-aca7-1566c2e67cc0',
#   'name': '1781 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '11109 Plank Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Spotsylvania',
#   'state_province': 'Virginia',
#   'postal_code': '22553-4258',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '5408412598',
#   'website_url': None,
#   'state': 'Virginia',
#   'street': '11109 Plank Rd'},
#  {'id': '896f26a1-d80e-4790-9287-026a86c1799d',
#   'name': '180 and Tapped',
#   'brewery_type': 'micro',
#   'address_1': '2010 A State Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Coraopolis',
#   'state_province': 'Pennsylvania',
#   'postal_code': '15108',
#   'country': 'United States',
#   'longitude': '-80.15020356',
#   'latitude': '40.50984957',
#   'phone': '4127375273',
#   'website_url': 'http://www.180andtapped.com',
#   'state': 'Pennsylvania',
#   'street': '2010 A State Ave'},
#  {'id': '46839a79-b7bf-4733-b91b-ce116d062a57',
#   'name': '1817 Brewery',
#   'brewery_type': 'micro',
#   'address_1': '100 B South Olive St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'okolona',
#   'state_province': 'Mississippi',
#   'postal_code': '38860',
#   'country': 'United States',
#   'longitude': '-88.750264',
#   'latitude': '34.001703',
#   'phone': '6623055907',
#   'website_url': None,
#   'state': 'Mississippi',
#   'street': '100 B South Olive St'},
#  {'id': '1a1b2165-73ed-40aa-b89b-56794d140f22',
#   'name': '1840 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '342 E Ward St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Milwaukee',
#   'state_province': 'Wisconsin',
#   'postal_code': '53207-1348',
#   'country': 'United States',
#   'longitude': '-87.90606942',
#   'latitude': '43.00436242',
#   'phone': '4142364056',
#   'website_url': 'http://www.1840brewing.com',
#   'state': 'Wisconsin',
#   'street': '342 E Ward St'},
#  {'id': 'fe6b9893-b93e-43d5-a9f6-3e0c89a3f13c',
#   'name': '1850 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mariposa',
#   'state_province': 'California',
#   'postal_code': '95338',
#   'country': 'United States',
#   'longitude': '-119.9036592',
#   'latitude': '37.570148',
#   'phone': None,
#   'website_url': 'http://www.1850restaurant.com',
#   'state': 'California',
#   'street': None},
#  {'id': 'b51f3cdf-60ff-4ae1-94a7-76906c7d62eb',
#   'name': '18th Street Brewery',
#   'brewery_type': 'micro',
#   'address_1': '5725 Miller Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Gary',
#   'state_province': 'Indiana',
#   'postal_code': '46403-2871',
#   'country': 'United States',
#   'longitude': '-87.26887786',
#   'latitude': '41.59928343',
#   'phone': None,
#   'website_url': 'http://www.18thstreetbrewery.com',
#   'state': 'Indiana',
#   'street': '5725 Miller Ave'},
#  {'id': 'add7f978-942e-4d56-b209-c80837a51d69',
#   'name': '18th Street Brewery',
#   'brewery_type': 'micro',
#   'address_1': '5417 Oakley Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Hammond',
#   'state_province': 'Indiana',
#   'postal_code': '46320-1817',
#   'country': 'United States',
#   'longitude': '-87.517422',
#   'latitude': '41.61556796',
#   'phone': None,
#   'website_url': None,
#   'state': 'Indiana',
#   'street': '5417 Oakley Ave'},
#  {'id': 'dbde8235-2b55-4d8b-8b1c-438155abe104',
#   'name': '1905 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '1301 S Chestnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Assumption',
#   'state_province': 'Illinois',
#   'postal_code': '62510-8504',
#   'country': 'United States',
#   'longitude': '-89.0503635',
#   'latitude': '39.5172564',
#   'phone': '2172549374',
#   'website_url': 'http://1905BrewingCompany.com',
#   'state': 'Illinois',
#   'street': '1301 S Chestnut St'},
#  {'id': '4f4b5b34-d572-4dff-a18f-47e507c073e6',
#   'name': '1912 Brewing',
#   'brewery_type': 'micro',
#   'address_1': '2045 N Forbes Blvd Ste 105',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Tucson',
#   'state_province': 'Arizona',
#   'postal_code': '85745-1444',
#   'country': 'United States',
#   'longitude': '-110.9927505',
#   'latitude': '32.24673727',
#   'phone': '5202564851',
#   'website_url': 'http://www.1912brewing.com',
#   'state': 'Arizona',
#   'street': '2045 N Forbes Blvd Ste 105'}]

# %%
# getting to use jason_normalize
from pandas import json_normalize
results = brewer_response.json()
flattened_data = json_normalize(results)
flattened_data
# When i decide to go visit the U.S. I know were to go :)
# Out:
#                                       id                             name  \
# 0   5128df48-79fc-4f0f-8b52-d06be54d0cec                 (405) Brewing Co
# 1   9c5a66c8-cc13-416f-a5d9-0a769c87d318                 (512) Brewing Co
# 2   34e8c68b-6146-453f-a4b9-1f6cd99a5ada          1 of Us Brewing Company
# 3   ef970757-fe42-416f-931d-722451f1f59c             10 Barrel Brewing Co
# 4   6d14b220-8926-4521-8d19-b98a2d6ec3db             10 Barrel Brewing Co
# 5   e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2             10 Barrel Brewing Co
# 6   e432899b-7f58-455f-9c7b-9a6e2130a1e0             10 Barrel Brewing Co
# 7   9f1852da-c312-42da-9a31-097bac81c4c0  10 Barrel Brewing Co - Bend Pub
# 8   ea4f30c0-bce6-416b-8904-fab4055a7362     10 Barrel Brewing Co - Boise
# ..                                   ...                              ...
# 41  84d621c4-81a5-44e6-aca7-1566c2e67cc0             1781 Brewing Company
# 42  896f26a1-d80e-4790-9287-026a86c1799d                   180 and Tapped
# 43  46839a79-b7bf-4733-b91b-ce116d062a57                     1817 Brewery
# 44  1a1b2165-73ed-40aa-b89b-56794d140f22             1840 Brewing Company
# 45  fe6b9893-b93e-43d5-a9f6-3e0c89a3f13c             1850 Brewing Company
# 46  b51f3cdf-60ff-4ae1-94a7-76906c7d62eb              18th Street Brewery
# 47  add7f978-942e-4d56-b209-c80837a51d69              18th Street Brewery
# 48  dbde8235-2b55-4d8b-8b1c-438155abe104             1905 Brewing Company
# 49  4f4b5b34-d572-4dff-a18f-47e507c073e6                     1912 Brewing
#
#    brewery_type                    address_1 address_2 address_3  \
# 0         micro               1716 Topeka St      None      None
# 1         micro        407 Radam Ln Ste F200      None      None
# 2         micro          8100 Washington Ave      None      None
# 3         large                    1501 E St      None      None
# 4         large                62970 18th St      None      None
# 5         large  1135 NW Galveston Ave Ste B      None      None
# 6         large          1411 NW Flanders St      None      None
# 7         large             62950 NE 18th St      None      None
# 8         large             826 W Bannock St      None      None
# ..          ...                          ...       ...       ...
# 41        micro               11109 Plank Rd      None      None
# 42        micro             2010 A State Ave      None      None
# 43        micro         100 B South Olive St      None      None
# 44        micro                342 E Ward St      None      None
# 45        micro                         None      None      None
# 46        micro              5725 Miller Ave      None      None
# 47        micro              5417 Oakley Ave      None      None
# 48        micro           1301 S Chestnut St      None      None
# 49        micro   2045 N Forbes Blvd Ste 105      None      None
#
#               city state_province postal_code        country  \
# 0           Norman       Oklahoma  73069-8224  United States
# 1           Austin          Texas  78745-1197  United States
# 2   Mount Pleasant      Wisconsin  53406-3920  United States
# 3        San Diego     California  92101-6618  United States
# 4             Bend         Oregon  97701-9847  United States
# 5             Bend         Oregon  97703-2465  United States
# 6         Portland         Oregon  97209-2620  United States
# 7             Bend         Oregon       97701  United States
# 8            Boise          Idaho  83702-5857  United States
# ..             ...            ...         ...            ...
# 41    Spotsylvania       Virginia  22553-4258  United States
# 42      Coraopolis   Pennsylvania       15108  United States
# 43         okolona    Mississippi       38860  United States
# 44       Milwaukee      Wisconsin  53207-1348  United States
# 45        Mariposa     California       95338  United States
# 46            Gary        Indiana  46403-2871  United States
# 47         Hammond        Indiana  46320-1817  United States
# 48      Assumption       Illinois  62510-8504  United States
# 49          Tucson        Arizona  85745-1444  United States
#
#              longitude           latitude       phone  \
# 0         -97.46818222        35.25738891  4058160490
# 1                 None               None  5129211545
# 2   -87.88336350209435  42.72010826899558  2624847553
# 3          -117.129593          32.714813  6195782311
# 4          -121.281706        44.08683531  5415851007
# 5         -121.3288021         44.0575649  5415851007
# 6         -122.6855056         45.5259786  5032241700
# 7         -121.2809536         44.0912109  5415851007
# 8          -116.202929          43.618516  2083445870
# ..                 ...                ...         ...
# 41                None               None  5408412598
# 42        -80.15020356        40.50984957  4127375273
# 43          -88.750264          34.001703  6623055907
# 44        -87.90606942        43.00436242  4142364056
# 45        -119.9036592          37.570148        None
# 46        -87.26887786        41.59928343        None
# 47          -87.517422        41.61556796        None
# 48         -89.0503635         39.5172564  2172549374
# 49        -110.9927505        32.24673727  5202564851
#
#                          website_url         state  \
# 0          http://www.405brewing.com      Oklahoma
# 1          http://www.512brewing.com         Texas
# 2       https://www.1ofusbrewing.com     Wisconsin
# 3                http://10barrel.com    California
# 4            http://www.10barrel.com        Oregon
# 5                               None        Oregon
# 6            http://www.10barrel.com        Oregon
# 7                               None        Oregon
# 8            http://www.10barrel.com         Idaho
# ..                               ...           ...
# 41                              None      Virginia
# 42       http://www.180andtapped.com  Pennsylvania
# 43                              None   Mississippi
# 44        http://www.1840brewing.com     Wisconsin
# 45     http://www.1850restaurant.com    California
# 46  http://www.18thstreetbrewery.com       Indiana
# 47                              None       Indiana
# 48     http://1905BrewingCompany.com      Illinois
# 49        http://www.1912brewing.com       Arizona
#
#                          street
# 0                1716 Topeka St
# 1         407 Radam Ln Ste F200
# 2           8100 Washington Ave
# 3                     1501 E St
# 4                 62970 18th St
# 5   1135 NW Galveston Ave Ste B
# 6           1411 NW Flanders St
# 7              62950 NE 18th St
# 8              826 W Bannock St
# ..                          ...
# 41               11109 Plank Rd
# 42             2010 A State Ave
# 43         100 B South Olive St
# 44                342 E Ward St
# 45                         None
# 46              5725 Miller Ave
# 47              5417 Oakley Ave
# 48           1301 S Chestnut St
# 49   2045 N Forbes Blvd Ste 105
#
# [50 rows x 16 columns]
